# %%
#Part A
import pandas as pd
import numpy as np
import keras

# %%
concrete_data = pd.read_csv('concrete_data.csv') #load data into the environment
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
concrete_data.isnull().sum() #check for null values
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
concrete_data_columns = concrete_data.columns
# All columns other than 'Strength' variable are input variables
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column is target variable

# %%
predictors.head() #glimpse of the predictors
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head() #glimpse of the target variable
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %%
n_cols = predictors.shape[1] # number of predictors
print(n_cols)
# Out:
# 8

# %%
#Import nencesaary modules from keras
from keras.models import Sequential
from keras.layers import Dense

# %%
#Building a regression model function definition
def regression_model():
  # create model
  model = Sequential()
  model.add(Dense(10, activation='relu', input_shape=(n_cols,))) #1 Hidden layer
  model.add(Dense(1)) #Output layer

  # compile model
  model.compile(optimizer='adam', loss='mean_squared_error')
  return model

# %%
#Step1: Test-Train split according to given constraints using sci-kit-learn library
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.30, random_state=30)

# %%
#Step2: Build the model
model = regression_model()
# Fit the model on train data
model.fit(X_train, y_train, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 23/23 - 1s - loss: 1542.2883 - 869ms/epoch - 38ms/step
# Epoch 2/50
# 23/23 - 0s - loss: 1528.9055 - 95ms/epoch - 4ms/step
# Epoch 3/50
# 23/23 - 0s - loss: 1514.5614 - 103ms/epoch - 4ms/step
# Epoch 4/50
# 23/23 - 0s - loss: 1490.2385 - 89ms/epoch - 4ms/step
# Epoch 5/50
# 23/23 - 0s - loss: 1449.7723 - 150ms/epoch - 7ms/step
# Epoch 6/50
# 23/23 - 0s - loss: 1386.6799 - 150ms/epoch - 7ms/step
# Epoch 7/50
# 23/23 - 0s - loss: 1293.2653 - 126ms/epoch - 5ms/step
# Epoch 8/50
# 23/23 - 0s - loss: 1162.9525 - 113ms/epoch - 5ms/step
# Epoch 9/50
# 23/23 - 0s - loss: 999.9078 - 86ms/epoch - 4ms/step
# Epoch 10/50
# 23/23 - 0s - loss: 812.1336 - 87ms/epoch - 4ms/step
# Epoch 11/50
# 23/23 - 0s - loss: 619.0037 - 81ms/epoch - 4ms/step
# Epoch 12/50
# 23/23 - 0s - loss: 447.8843 - 83ms/epoch - 4ms/step
# Epoch 13/50
# 23/23 - 0s - loss: 320.0961 - 93ms/epoch - 4ms/step
# Epoch 14/50
# 23/23 - 0s - loss: 240.0348 - 82ms/epoch - 4ms/step
# Epoch 15/50
# 23/23 - 0s - loss: 202.1967 - 87ms/epoch - 4ms/step
# Epoch 16/50
# 23/23 - 0s - loss: 185.3677 - 77ms/epoch - 3ms/step
# Epoch 17/50
# 23/23 - 0s - loss: 177.4945 - 92ms/epoch - 4ms/step
# Epoch 18/50
# 23/23 - 0s - loss: 172.4495 - 87ms/epoch - 4ms/step
# Epoch 19/50
# 23/23 - 0s - loss: 168.4328 - 77ms/epoch - 3ms/step
# Epoch 20/50
# 23/23 - 0s - loss: 164.5966 - 115ms/epoch - 5ms/step
# Epoch 21/50
# 23/23 - 0s - loss: 161.2312 - 131ms/epoch - 6ms/step
# Epoch 22/50
# 23/23 - 0s - loss: 158.3587 - 125ms/epoch - 5ms/step
# Epoch 23/50
# 23/23 - 0s - loss: 155.3537 - 127ms/epoch - 6ms/step
# Epoch 24/50
# 23/23 - 0s - loss: 152.7600 - 78ms/epoch - 3ms/step
# Epoch 25/50
# 23/23 - 0s - loss: 150.4168 - 102ms/epoch - 4ms/step
# Epoch 26/50
# 23/23 - 0s - loss: 148.4181 - 126ms/epoch - 5ms/step
# Epoch 27/50
# 23/23 - 0s - loss: 146.1982 - 125ms/epoch - 5ms/step
# Epoch 28/50
# 23/23 - 0s - loss: 144.3283 - 114ms/epoch - 5ms/step
# Epoch 29/50
# 23/23 - 0s - loss: 142.3221 - 97ms/epoch - 4ms/step
# Epoch 30/50
# 23/23 - 0s - loss: 140.7728 - 72ms/epoch - 3ms/step
# Epoch 31/50
# 23/23 - 0s - loss: 139.1555 - 61ms/epoch - 3ms/step
# Epoch 32/50
# 23/23 - 0s - loss: 137.5939 - 61ms/epoch - 3ms/step
# Epoch 33/50
# 23/23 - 0s - loss: 136.1483 - 62ms/epoch - 3ms/step
# Epoch 34/50
# 23/23 - 0s - loss: 134.8975 - 62ms/epoch - 3ms/step
# Epoch 35/50
# 23/23 - 0s - loss: 133.5903 - 56ms/epoch - 2ms/step
# Epoch 36/50
# 23/23 - 0s - loss: 132.7392 - 67ms/epoch - 3ms/step
# Epoch 37/50
# 23/23 - 0s - loss: 131.4089 - 118ms/epoch - 5ms/step
# Epoch 38/50
# 23/23 - 0s - loss: 130.3621 - 93ms/epoch - 4ms/step
# Epoch 39/50
# 23/23 - 0s - loss: 129.4425 - 107ms/epoch - 5ms/step
# Epoch 40/50
# 23/23 - 0s - loss: 128.5273 - 114ms/epoch - 5ms/step
# Epoch 41/50
# 23/23 - 0s - loss: 127.6194 - 102ms/epoch - 4ms/step
# Epoch 42/50
# 23/23 - 0s - loss: 126.8153 - 97ms/epoch - 4ms/step
# Epoch 43/50
# 23/23 - 0s - loss: 125.8905 - 86ms/epoch - 4ms/step
# Epoch 44/50
# 23/23 - 0s - loss: 125.2643 - 170ms/epoch - 7ms/step
# Epoch 45/50
# 23/23 - 0s - loss: 124.6348 - 258ms/epoch - 11ms/step
# Epoch 46/50
# 23/23 - 0s - loss: 123.8866 - 159ms/epoch - 7ms/step
# Epoch 47/50
# 23/23 - 0s - loss: 123.1761 - 51ms/epoch - 2ms/step
# Epoch 48/50
# 23/23 - 0s - loss: 122.5425 - 52ms/epoch - 2ms/step
# Epoch 49/50
# 23/23 - 0s - loss: 122.0321 - 52ms/epoch - 2ms/step
# Epoch 50/50
# 23/23 - 0s - loss: 121.1395 - 47ms/epoch - 2ms/step

# %%
#Predicting the output for the test dataset
predictions=model.predict(X_test)
print(len(predictions))
# Out:
# 10/10 [==============================] - 0s 3ms/step
# 309

# %%
#Step3: Calculate the MSE for the test datset
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test, predictions)
print(mse)
# Out:
# 167.13477490997033

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
mse_ls=[]
#Repeat steps(1-3) 50 times
for i in range (50):
  X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.30, random_state=30)
  model = regression_model()
  model.fit(X_train, y_train, epochs=50, verbose=2)
  predictions=model.predict(X_test)
  mse=mean_squared_error(y_test, predictions)
  mse_ls.append(mse)

# %%
print(mse_ls) #list of 50 errors

# %%
#Calculate the mean and standard deviation
import numpy as np
mean_errors=np.mean(mse_ls) #mean
std_errors=np.std(mse_ls) #standard deviation
print(mean_errors,std_errors) #----> Ans of Part A of assign
